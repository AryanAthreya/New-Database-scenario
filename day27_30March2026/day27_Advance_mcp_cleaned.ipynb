# %%
# 🎬 🎓 SCENARIO: “College Smart Assistant System”
# 🏫 Background Story

# A college builds an AI-powered student assistant.

# 👉 Students can ask:

# “What is my attendance?”
# “What are my marks?”

# 👉 Instead of manually checking portals,
# 👉 AI fetches it instantly.
# ================================
# STEP 1: Install Gradio
# ================================
# !pip install gradio


# ================================
# STEP 2: Dummy Database (Tool Layer)
# ================================
students = students = {
    "101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "102": {"name": "Priya", "attendance": 92, "marks": 88},
    "103": {"name": "Amit", "attendance": 76, "marks": 69},
    "104": {"name": "Sneha", "attendance": 89, "marks": 91},
    "105": {"name": "Vikas", "attendance": 81, "marks": 73},
    "106": {"name": "Neha", "attendance": 95, "marks": 87},
    "107": {"name": "Rohit", "attendance": 68, "marks": 64},
    "108": {"name": "Pooja", "attendance": 90, "marks": 85},
    "109": {"name": "Arjun", "attendance": 84, "marks": 79},
    "110": {"name": "Kavya", "attendance": 93, "marks": 92},
    "111": {"name": "Manish", "attendance": 72, "marks": 70},
    "112": {"name": "Anjali", "attendance": 88, "marks": 86},
    "113": {"name": "Suresh", "attendance": 77, "marks": 71},
    "114": {"name": "Divya", "attendance": 91, "marks": 89},
    "115": {"name": "Karan", "attendance": 83, "marks": 76},
    "116": {"name": "Meera", "attendance": 94, "marks": 90},
    "117": {"name": "Deepak", "attendance": 69, "marks": 65},
    "118": {"name": "Nisha", "attendance": 87, "marks": 84},
    "119": {"name": "Yash", "attendance": 80, "marks": 75},
    "120": {"name": "Riya", "attendance": 96, "marks": 93},
    "121": {"name": "Gaurav", "attendance": 74, "marks": 68},
    "122": {"name": "Isha", "attendance": 89, "marks": 88},
    "123": {"name": "Harsh", "attendance": 82, "marks": 77},
    "124": {"name": "Simran", "attendance": 90, "marks": 86},
    "125": {"name": "Nitin", "attendance": 78, "marks": 72},
    "126": {"name": "Payal", "attendance": 92, "marks": 91},
    "127": {"name": "Ajay", "attendance": 70, "marks": 66},
    "128": {"name": "Shreya", "attendance": 95, "marks": 94},
    "129": {"name": "Varun", "attendance": 84, "marks": 80},
    "130": {"name": "Tanvi", "attendance": 88, "marks": 87},
    "131": {"name": "Akash", "attendance": 76, "marks": 74},
    "132": {"name": "Komal", "attendance": 91, "marks": 89},
    "133": {"name": "Rakesh", "attendance": 73, "marks": 69},
    "134": {"name": "Alka", "attendance": 93, "marks": 90},
    "135": {"name": "Sanjay", "attendance": 79, "marks": 75},
    "136": {"name": "Preeti", "attendance": 94, "marks": 92},
    "137": {"name": "Mohit", "attendance": 67, "marks": 63},
    "138": {"name": "Swati", "attendance": 89, "marks": 85},
    "139": {"name": "Ankit", "attendance": 82, "marks": 78},
    "140": {"name": "Rekha", "attendance": 90, "marks": 88},
    "141": {"name": "Sachin", "attendance": 75, "marks": 70},
    "142": {"name": "Jyoti", "attendance": 92, "marks": 91},
    "143": {"name": "Ravi", "attendance": 80, "marks": 76},
    "144": {"name": "Neelam", "attendance": 87, "marks": 83},
    "145": {"name": "Lokesh", "attendance": 78, "marks": 72},
    "146": {"name": "Seema", "attendance": 93, "marks": 89},
    "147": {"name": "Pankaj", "attendance": 74, "marks": 68},
    "148": {"name": "Aarti", "attendance": 91, "marks": 90},
    "149": {"name": "Tarun", "attendance": 83, "marks": 79},
    "150": {"name": "Bhavna", "attendance": 95, "marks": 93},
    "151": {"name": "Kunal", "attendance": 77, "marks": 71},
    "152": {"name": "Monika", "attendance": 88, "marks": 86}
}


# ================================
# STEP 3: Tool Functions (MCP Tools)
# ================================
def get_attendance(student_id):
    if student_id in students:
        return f"📊 Attendance: {students[student_id]['attendance']}%"
    return "❌ Student not found"


def get_marks(student_id):
    if student_id in students:
        return f"📝 Marks: {students[student_id]['marks']}"
    return "❌ Student not found"


# ================================
# STEP 4: Security Layer
# ================================
def secure_access(user_id, requested_id):
    return user_id == requested_id


# ================================
# STEP 5: MCP Agent Logic
# ================================
def mcp_agent(message, student_id, history):

    # Simulate logged-in user (for demo)
    user_id = student_id

    # Security Check
    if not secure_access(user_id, student_id):
        return "🚫 Access Denied", history

    # Tool Invocation Logic
    message_lower = message.lower()

    if "attendance" in message_lower:
        response = get_attendance(student_id)

    elif "marks" in message_lower:
        response = get_marks(student_id)

    elif "hello" in message_lower or "hi" in message_lower:
        response = "👋 Hello! Ask me about attendance or marks."

    else:
        response = "🤖 I can help with attendance or marks."

    # Maintain chat history
    history.append((message, response))

    return "", history


# ================================
# STEP 6: Gradio Chat UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🎓 Student MCP Agent (Gradio Version)")

    student_id = gr.Textbox(label="Enter Student ID (e.g., 101)")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Ask your question (name , attendence, marks)")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, student_id, state],
        outputs=[msg, chatbot]
    )

# ================================
# STEP 7: Launch App (Public URL)
# ================================
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_1032/3680969924.py:144: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# /tmp/ipykernel_1032/3680969924.py:144: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot()
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://262a48dd7b9e7641a9.gradio.live
#
# ...

# %%
# ======================================
# STEP 1: Install Libraries
# ======================================
# !pip install groq gradio


# ======================================
# STEP 2: API Key Setup (Colab + Local)
# ======================================
import os

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 3: Dummy Database
# ======================================
students = students = {
    "101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "102": {"name": "Priya", "attendance": 92, "marks": 88},

    "103": {"name": "Amit", "attendance": 76, "marks": 69},
    "104": {"name": "Sneha", "attendance": 89, "marks": 91},
    "105": {"name": "Vikas", "attendance": 81, "marks": 73},
    "106": {"name": "Neha", "attendance": 95, "marks": 87},
    "107": {"name": "Rohit", "attendance": 68, "marks": 64},
    "108": {"name": "Pooja", "attendance": 90, "marks": 85},
    "109": {"name": "Arjun", "attendance": 84, "marks": 79},
    "110": {"name": "Kavya", "attendance": 93, "marks": 92},
    "111": {"name": "Manish", "attendance": 72, "marks": 70},
    "112": {"name": "Anjali", "attendance": 88, "marks": 86},
    "113": {"name": "Suresh", "attendance": 77, "marks": 71},
    "114": {"name": "Divya", "attendance": 91, "marks": 89},
    "115": {"name": "Karan", "attendance": 83, "marks": 76},
    "116": {"name": "Meera", "attendance": 94, "marks": 90},
    "117": {"name": "Deepak", "attendance": 69, "marks": 65},
    "118": {"name": "Nisha", "attendance": 87, "marks": 84},
    "119": {"name": "Yash", "attendance": 80, "marks": 75},
    "120": {"name": "Riya", "attendance": 96, "marks": 93},
    "121": {"name": "Gaurav", "attendance": 74, "marks": 68},
    "122": {"name": "Isha", "attendance": 89, "marks": 88},
    "123": {"name": "Harsh", "attendance": 82, "marks": 77},
    "124": {"name": "Simran", "attendance": 90, "marks": 86},
    "125": {"name": "Nitin", "attendance": 78, "marks": 72},
    "126": {"name": "Payal", "attendance": 92, "marks": 91},
    "127": {"name": "Ajay", "attendance": 70, "marks": 66},
    "128": {"name": "Shreya", "attendance": 95, "marks": 94},
    "129": {"name": "Varun", "attendance": 84, "marks": 80},
    "130": {"name": "Tanvi", "attendance": 88, "marks": 87},
    "131": {"name": "Akash", "attendance": 76, "marks": 74},
    "132": {"name": "Komal", "attendance": 91, "marks": 89},
    "133": {"name": "Rakesh", "attendance": 73, "marks": 69},
    "134": {"name": "Alka", "attendance": 93, "marks": 90},
    "135": {"name": "Sanjay", "attendance": 79, "marks": 75},
    "136": {"name": "Preeti", "attendance": 94, "marks": 92},
    "137": {"name": "Mohit", "attendance": 67, "marks": 63},
    "138": {"name": "Swati", "attendance": 89, "marks": 85},
    "139": {"name": "Ankit", "attendance": 82, "marks": 78},
    "140": {"name": "Rekha", "attendance": 90, "marks": 88},
    "141": {"name": "Sachin", "attendance": 75, "marks": 70},
    "142": {"name": "Jyoti", "attendance": 92, "marks": 91},
    "143": {"name": "Ravi", "attendance": 80, "marks": 76},
    "144": {"name": "Neelam", "attendance": 87, "marks": 83},
    "145": {"name": "Lokesh", "attendance": 78, "marks": 72},
    "146": {"name": "Seema", "attendance": 93, "marks": 89},
    "147": {"name": "Pankaj", "attendance": 74, "marks": 68},
    "148": {"name": "Aarti", "attendance": 91, "marks": 90},
    "149": {"name": "Tarun", "attendance": 83, "marks": 79},
    "150": {"name": "Bhavna", "attendance": 95, "marks": 93},
    "151": {"name": "Kunal", "attendance": 77, "marks": 71},
    "152": {"name": "Monika", "attendance": 88, "marks": 86}
}


# ======================================
# STEP 4: Tool Functions
# ======================================
def get_attendance(student_id):
    student = students.get(student_id)
    if student:
        return f"📊 {student['name']}'s Attendance: {student['attendance']}%"
    return "❌ Student not found"


def get_marks(student_id):
    student = students.get(student_id)
    if student:
        return f"📝 {student['name']}'s Marks: {student['marks']}"
    return "❌ Student not found"


# ======================================
# STEP 5: Tool Decision (STRICT)
# ======================================
def decide_tool(query):
    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0,  # 🔥 IMPORTANT (no randomness)
            messages=[
                {
                    "role": "system",
                    "content": (
                        "You are a strict classifier.\n"
                        "Only return ONE word:\n"
                        "attendance OR marks\n"
                        "No explanation."
                    )
                },
                {
                    "role": "user",
                    "content": query
                }
            ]
        )

        tool = response.choices[0].message.content.strip().lower()

        # Safety filter
        if tool not in ["attendance", "marks"]:
            return "unknown"

        return tool

    except Exception as e:
        print("❌ Groq Error:", e)
        return "fallback"


# ======================================
# STEP 6: MCP Agent (Core Logic)
# ======================================
def mcp_agent(message, student_id, history):

    if not student_id:
        response = "⚠️ Please enter Student ID"
    else:
        tool = decide_tool(message)

        if tool == "attendance":
            response = get_attendance(student_id)

        elif tool == "marks":
            response = get_marks(student_id)

        elif tool == "fallback":
            # backup logic
            msg = message.lower()
            if "attendance" in msg:
                response = get_attendance(student_id)
            elif "marks" in msg:
                response = get_marks(student_id)
            else:
                response = "⚠️ Couldn't understand. Try asking about marks or attendance."

        else:
            response = "🤖 Ask about marks or attendance only."

    history.append((message, response))
    return "", history


# ======================================
# STEP 7: Gradio UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🚀 MCP Agent with Groq (Optimized)")

    student_id = gr.Textbox(label="Enter Student ID (101-152)")
    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, student_id, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 8: Launch App
# ======================================
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_1032/1256352716.py:180: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_1032/1256352716.py:180: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f4b544e956a05cf9af.gradio.live
#
# ...

# %%
# 🎬 🎓 SCENARIO: College Smart Assistant System

# ================================
# STEP 1: Install Libraries
# ================================
# !pip install gradio groq


# ================================
# STEP 2: Setup Groq Client
# ================================
import os
from groq import Groq

# For Colab
try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# ================================
# STEP 3: Dummy Database
# ================================
students = students = {
    "101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "102": {"name": "Priya", "attendance": 92, "marks": 88},

    "103": {"name": "Amit", "attendance": 76, "marks": 69},
    "104": {"name": "Sneha", "attendance": 89, "marks": 91},
    "105": {"name": "Vikas", "attendance": 81, "marks": 73},
    "106": {"name": "Neha", "attendance": 95, "marks": 87},
    "107": {"name": "Rohit", "attendance": 68, "marks": 64},
    "108": {"name": "Pooja", "attendance": 90, "marks": 85},
    "109": {"name": "Arjun", "attendance": 84, "marks": 79},
    "110": {"name": "Kavya", "attendance": 93, "marks": 92},
    "111": {"name": "Manish", "attendance": 72, "marks": 70},
    "112": {"name": "Anjali", "attendance": 88, "marks": 86},
    "113": {"name": "Suresh", "attendance": 77, "marks": 71},
    "114": {"name": "Divya", "attendance": 91, "marks": 89},
    "115": {"name": "Karan", "attendance": 83, "marks": 76},
    "116": {"name": "Meera", "attendance": 94, "marks": 90},
    "117": {"name": "Deepak", "attendance": 69, "marks": 65},
    "118": {"name": "Nisha", "attendance": 87, "marks": 84},
    "119": {"name": "Yash", "attendance": 80, "marks": 75},
    "120": {"name": "Riya", "attendance": 96, "marks": 93},
    "121": {"name": "Gaurav", "attendance": 74, "marks": 68},
    "122": {"name": "Isha", "attendance": 89, "marks": 88},
    "123": {"name": "Harsh", "attendance": 82, "marks": 77},
    "124": {"name": "Simran", "attendance": 90, "marks": 86},
    "125": {"name": "Nitin", "attendance": 78, "marks": 72},
    "126": {"name": "Payal", "attendance": 92, "marks": 91},
    "127": {"name": "Ajay", "attendance": 70, "marks": 66},
    "128": {"name": "Shreya", "attendance": 95, "marks": 94},
    "129": {"name": "Varun", "attendance": 84, "marks": 80},
    "130": {"name": "Tanvi", "attendance": 88, "marks": 87},
    "131": {"name": "Akash", "attendance": 76, "marks": 74},
    "132": {"name": "Komal", "attendance": 91, "marks": 89},
    "133": {"name": "Rakesh", "attendance": 73, "marks": 69},
    "134": {"name": "Alka", "attendance": 93, "marks": 90},
    "135": {"name": "Sanjay", "attendance": 79, "marks": 75},
    "136": {"name": "Preeti", "attendance": 94, "marks": 92},
    "137": {"name": "Mohit", "attendance": 67, "marks": 63},
    "138": {"name": "Swati", "attendance": 89, "marks": 85},
    "139": {"name": "Ankit", "attendance": 82, "marks": 78},
    "140": {"name": "Rekha", "attendance": 90, "marks": 88},
    "141": {"name": "Sachin", "attendance": 75, "marks": 70},
    "142": {"name": "Jyoti", "attendance": 92, "marks": 91},
    "143": {"name": "Ravi", "attendance": 80, "marks": 76},
    "144": {"name": "Neelam", "attendance": 87, "marks": 83},
    "145": {"name": "Lokesh", "attendance": 78, "marks": 72},
    "146": {"name": "Seema", "attendance": 93, "marks": 89},
    "147": {"name": "Pankaj", "attendance": 74, "marks": 68},
    "148": {"name": "Aarti", "attendance": 91, "marks": 90},
    "149": {"name": "Tarun", "attendance": 83, "marks": 79},
    "150": {"name": "Bhavna", "attendance": 95, "marks": 93},
    "151": {"name": "Kunal", "attendance": 77, "marks": 71},
    "152": {"name": "Monika", "attendance": 88, "marks": 86}
}


# ================================
# STEP 4: Tool Functions
# ================================
def get_attendance(student_id):
    student = students.get(student_id)
    if student:
        return f"📊 {student['name']}'s Attendance: {student['attendance']}%"
    return "❌ Student not found"


def get_marks(student_id):
    student = students.get(student_id)
    if student:
        return f"📝 {student['name']}'s Marks: {student['marks']}"
    return "❌ Student not found"


# ================================
# STEP 5: Smart Router (LLM)
# ================================
def route_query(message, history):
    try:
        messages = [
            {
                "role": "system",
                "content": (
                    "You are an AI assistant with tool access.\n\n"
                    "Available tools:\n"
                    "1. get_attendance(student_id)\n"
                    "2. get_marks(student_id)\n\n"
                    "Rules:\n"
                    "- If user asks about attendance → return: TOOL:attendance\n"
                    "- If user asks about marks → return: TOOL:marks\n"
                    "- Otherwise → respond normally\n"
                )
            }
        ]

        # Add memory
        for user_msg, bot_msg in history:
            messages.append({"role": "user", "content": user_msg})
            messages.append({"role": "assistant", "content": bot_msg})

        messages.append({"role": "user", "content": message})

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0.3,
            messages=messages
        )

        return response.choices[0].message.content.strip()

    except Exception as e:
        print("❌ Groq Error:", e)
        return "ERROR"


# ================================
# STEP 6: MCP Agent
# ================================
def mcp_agent(message, student_id, history):

    if not student_id:
        response = "⚠️ Please enter Student ID"
        history.append((message, response))
        return "", history

    reply = route_query(message, history)

    # Tool handling
    if reply.startswith("TOOL:attendance"):
        response = get_attendance(student_id)

    elif reply.startswith("TOOL:marks"):
        response = get_marks(student_id)

    elif reply == "ERROR":
        response = "⚠️ Something went wrong."

    else:
        response = reply  # LLM normal response

    history.append((message, response))
    return "", history


# ================================
# STEP 7: Gradio UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🚀 College Smart Assistant")

    student_id = gr.Textbox(label="Enter Student ID")
    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, student_id, state],
        outputs=[msg, chatbot]
    )


# ================================
# STEP 8: Launch App
# ================================
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_1032/2050648964.py:182: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_1032/2050648964.py:182: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://28594d1a44d39a6b35.gradio.live
#
# ...

# %% [markdown]
# SCENARIO: “Hospital Smart Assistant System”
# 🏥 Background Story
# A large hospital deploys an AI-powered patient assistant.
# 👉 Patients can ask:
# - “What is my appointment schedule?”
# - “What are my latest test results?”
# 👉 Instead of calling reception or logging into multiple portals,
# 👉 AI fetches it instantly, providing secure, real-time updates.

# %%
# ==========================================
# HOSPITAL SMART ASSISTANT SYSTEM
# ==========================================

import datetime

# -------------------------------
# Mock Database (for demo)
# -------------------------------
patients_db = {
    "P001": {
        "name": "Aryan",
        "dob": "2005-05-10",
        "appointments": [
            {"date": "2026-04-02", "doctor": "Dr. Sharma", "department": "Cardiology"},
            {"date": "2026-04-10", "doctor": "Dr. Mehta", "department": "Neurology"}
        ],
        "test_results": [
            {"test": "Blood Test", "result": "Normal", "date": "2026-03-25"},
            {"test": "ECG", "result": "Minor Irregularity", "date": "2026-03-28"}
        ]
    }
}

# -------------------------------
# Authentication (Basic Security)
# -------------------------------
def authenticate(patient_id):
    if patient_id in patients_db:
        return True
    return False

# -------------------------------
# Fetch Appointment Data
# -------------------------------
def get_appointments(patient_id):
    patient = patients_db.get(patient_id)
    if not patient:
        return "❌ Patient not found"

    appointments = patient["appointments"]

    if not appointments:
        return "No upcoming appointments."

    response = "\n📅 Your Appointments:\n"
    for appt in appointments:
        response += f"- {appt['date']} with {appt['doctor']} ({appt['department']})\n"

    return response

# -------------------------------
# Fetch Test Results
# -------------------------------
def get_test_results(patient_id):
    patient = patients_db.get(patient_id)
    if not patient:
        return "❌ Patient not found"

    tests = patient["test_results"]

    if not tests:
        return "No test results available."

    response = "\n🧪 Latest Test Results:\n"
    for test in tests:
        response += f"- {test['test']} ({test['date']}): {test['result']}\n"

    return response

# -------------------------------
# AI Assistant Logic
# -------------------------------
def smart_assistant():
    print("🏥 Welcome to Hospital Smart Assistant")
    patient_id = input("Enter Patient ID: ")

    # Authentication check
    if not authenticate(patient_id):
        print("❌ Access Denied. Invalid Patient ID.")
        return

    print("✅ Access Granted!\n")

    while True:
        print("\n💬 Ask your query:")
        print("1. Appointment Schedule")
        print("2. Test Results")
        print("3. Exit")

        choice = input("Enter choice (1/2/3): ")

        if choice == "1":
            print(get_appointments(patient_id))

        elif choice == "2":
            print(get_test_results(patient_id))

        elif choice == "3":
            print("👋 Thank you! Stay healthy.")
            break

        else:
            print("❌ Invalid choice. Try again.")

# -------------------------------
# Run System
# -------------------------------
if __name__ == "__main__":
    smart_assistant()
# Out:
# 🏥 Welcome to Hospital Smart Assistant
# Enter Patient ID: P001
# ✅ Access Granted!
#
#
# 💬 Ask your query:
# 1. Appointment Schedule
# 2. Test Results
# 3. Exit
# Enter choice (1/2/3): 2
#
# 🧪 Latest Test Results:
# - Blood Test (2026-03-25): Normal
# - ECG (2026-03-28): Minor Irregularity
#
#
# 💬 Ask your query:
# 1. Appointment Schedule
# 2. Test Results
# 3. Exit
# Enter choice (1/2/3): 1
#
# 📅 Your Appointments:
# - 2026-04-02 with Dr. Sharma (Cardiology)
# - 2026-04-10 with Dr. Mehta (Neurology)
#
#
# 💬 Ask your query:
# 1. Appointment Schedule
# 2. Test Results
# 3. Exit
# Enter choice (1/2/3): 3
# 👋 Thank you! Stay healthy.

# %%
# SCENARIO: “AI Banking Assistant with Role-Based Access”
# 🏦 Background Story

# A bank builds an AI assistant to help users:

# Check account balance
# View transactions
# Approve loans
# Manage customer accounts

# 👉 But not everyone can do everything

# 🧑‍🤝‍🧑 Roles in the Bank
# Role	Description
# 👤 Customer	Bank account holder
# 👨‍💼 Employee	Bank staff
# 🧑‍💼 Manager	Branch manager
# 🔐 Permissions (RBAC)
# Action	Customer	Employee	Manager
# View own balance	✅	✅	✅
# View others' accounts	❌	✅	✅
# Approve loan	❌	❌	✅
# View all transactions	❌	✅	✅


# ======================================
# STEP 1: Install Libraries
# ======================================
# !pip install groq gradio


# ======================================
# STEP 2: Load API Key from Colab Secrets
# ======================================
from google.colab import userdata

groq_api_key = userdata.get("GROQ_API_KEY")

if not groq_api_key:
    raise ValueError("❌ GROQ_API_KEY not found in Colab Secrets")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 3: Dummy Bank Database
# ======================================
accounts = {
    "1001": {"name": "Amit", "balance": 50000},
    "1002": {"name": "Neha", "balance": 75000}
}


# ======================================
# STEP 4: Tool Functions (APIs)
# ======================================
def get_balance(account_id):
    if account_id in accounts:
        return f"💰 Balance of {account_id}: ₹{accounts[account_id]['balance']}"
    return "❌ Account not found"


def approve_loan(account_id):
    if account_id in accounts:
        return f"🏦 Loan approved for account {account_id}"
    return "❌ Account not found"


# ======================================
# STEP 5: RBAC Security Layer
# ======================================
def secure_access(role, user_account, requested_account, action):

    # Manager → full access
    if role == "manager":
        return True

    # Employee → can view all but cannot approve loans
    elif role == "employee":
        if action == "approve_loan":
            return False
        return True

    # Customer → only own account, no loan approval
    elif role == "customer":
        return user_account == requested_account and action != "approve_loan"

    return False


# ======================================
# STEP 6: MCP Tool Decision via LLM
# ======================================
def decide_action(query):
    try:
        prompt = f"""
        You are an AI banking assistant.

        Decide which action to take:
        - get_balance
        - approve_loan

        Rules:
        - Balance related queries → get_balance
        - Loan approval queries → approve_loan

        Return ONLY the action name.

        Query: {query}
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[{"role": "user", "content": prompt}]
        )

        action = response.choices[0].message.content.strip().lower()
        return action

    except Exception as e:
        print("❌ Groq Error:", e)
        return "fallback"


# ======================================
# STEP 7: MCP Agent (Core Logic)
# ======================================
def banking_agent(message, role, user_account, requested_account, history):

    # Input validation
    if not user_account:
        response = "⚠️ Please enter your account ID"
        history.append((message, response))
        return "", history

    if not requested_account:
        requested_account = user_account  # default to own account

    # Step 1: LLM decides action
    action = decide_action(message)

    # Step 2: RBAC Security Check
    if not secure_access(role, user_account, requested_account, action):
        response = "🚫 Access Denied: You are not authorized"

    else:
        # Step 3: Tool Invocation
        if "balance" in action:
            response = get_balance(requested_account)

        elif "loan" in action:
            response = approve_loan(requested_account)

        # Fallback if LLM fails
        elif action == "fallback":
            msg_lower = message.lower()
            if "balance" in msg_lower:
                response = get_balance(requested_account)
            elif "loan" in msg_lower:
                response = approve_loan(requested_account)
            else:
                response = "⚠️ Could not understand request"

        else:
            response = "🤖 Try asking about balance or loan"

    # Save chat history
    history.append((message, response))

    return "", history


# ======================================
# STEP 8: Gradio UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🏦 AI Banking Assistant (MCP + RBAC + Groq)")

    role = gr.Dropdown(
        ["customer", "employee", "manager"],
        label="Select Role"
    )

    user_account = gr.Textbox(label="Your Account ID (e.g., 1001)")
    requested_account = gr.Textbox(label="Target Account ID (optional)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        banking_agent,
        inputs=[msg, role, user_account, requested_account, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 9: Launch App
# ======================================
demo.launch(share=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 kB 6.8 MB/s eta 0:00:00
# ...
# /tmp/ipykernel_3408/3234274250.py:191: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_3408/3234274250.py:191: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://061f2c410f968438a6.gradio.live
#
# ...

# %%
# ======================================
# STEP 1: Install Libraries
# ======================================
# !pip install groq nest_asyncio


# ======================================K
# STEP 2: Load Groq API Key (Colab Secret)
# ======================================
from google.colab import userdata
groq_api_key = userdata.get("GROQ_API_KEY")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 3: MOCK TOOLS (Simulating MCP Tools)
# ======================================

import asyncio
import random
import nest_asyncio

# Apply nest_asyncio to allow nested event loops
nest_asyncio.apply()

async def web_search(query):
    await asyncio.sleep(1)  # simulate delay
    return f"📰 News about {query}: Market is growing fast."

async def get_stock_data(company):
    await asyncio.sleep(1)
    price = random.randint(100, 500)
    return f"📈 Stock price of {company}: ${price}"

async def fetch_company_profile(company):
    await asyncio.sleep(1)
    return f"👥 {company} has 5000 employees, HQ in USA"


# ======================================
# STEP 4: PARALLEL TOOL INVOCATION
# ======================================

async def parallel_research(company):

    results = await asyncio.gather(
        web_search(company),
        get_stock_data(company),
        fetch_company_profile(company),
        return_exceptions=True
    )

    news, stock, profile = results

    return {
        "news": news if not isinstance(news, Exception) else "News unavailable",
        "stock": stock if not isinstance(stock, Exception) else "Stock unavailable",
        "profile": profile if not isinstance(profile, Exception) else "Profile unavailable"
    }


# ======================================
# STEP 5: CHAINED TOOL INVOCATION USING GROQ
# ======================================

def analyse_text(text):
    response = client.chat.completions.create(
    model="llama-3.3-70b-versatile", # Updated model name to a currently available Groq model
        messages=[{
            "role": "user",
            "content": f"Analyze this data and give key insights:\n{text}"
        }]
    )
    return response.choices[0].message.content


def generate_report(analysis, company):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile", # Updated model name to a currently available Groq model
        messages=[{
            "role": "user",
            "content": f"Create a professional report for {company}:\n{analysis}"
        }]
    )
    return response.choices[0].message.content


# ======================================
# STEP 6: FULL MCP PIPELINE
# ======================================

async def full_pipeline(company):

    # Step 1: Parallel Data Collection
    data = await parallel_research(company)

    combined_text = f"""
    News: {data['news']}
    Stock: {data['stock']}
    Profile: {data['profile']}
    """

    # Step 2: Analysis (LLM)
    analysis = analyse_text(combined_text)

    # Step 3: Report Generation (LLM)
    report = generate_report(analysis, company)

    return report


# ======================================
# STEP 7: RUN THE SYSTEM
# ======================================

company_name = "Tesla"

# Use asyncio.run() after applying nest_asyncio
result = asyncio.run(full_pipeline(company_name))

print("📊 FINAL REPORT:\n")
print(result)
# Out:
# ...
# 📊 FINAL REPORT:
#
# **Tesla Inc. Market Analysis and Insights Report**
#
# **Executive Summary:**
# This report provides an analysis of Tesla Inc. based on the provided data, highlighting key insights into the company's market growth, stock performance, and company profile. The report also explores potential implications of this data, including investment opportunities, job market trends, and industry developments.
#
# **Introduction:**
# Tesla Inc. is a leading player in the electric vehicle and renewable energy sectors. With a significant workforce and a strong presence in the North American market, Tesla is well-positioned to capitalize on the growing demand for sustainable energy solutions.
#
# **Key Insights:**
#
# ...

# %% [markdown]
# SCENARIO: “Banking Smart Assistant System”
# 🏦 Background Story
# A major bank launches an AI-powered customer assistant.
# 👉 Customers can ask:
# - “What is my account balance?”
# - “Show me my last 5 transactions.”
# - “When is my loan EMI due?”
# 👉 Instead of logging into apps or waiting on customer service calls,
# 👉 AI fetches the information instantly, securely, and in real time.
#
# ⚙️ Core Idea:
# Just like the hospital and college scenarios, the assistant removes manual checking, centralizes financial data, and makes access instant.
# 💡 Impact:
# - Saves customers time.
# - Reduces load on call centers.
# - Provides personalized financial insights on demand.

# %%
# ================================
# STEP 1: Install Gradio
# ================================
# !pip install gradio


# ================================
# STEP 2: Dummy Database (Tool Layer)
# ================================
customers = {
    "C101": {
        "name": "Amit Sharma",
        "balance": "₹85,000",
        "transactions": [
            "₹2000 - Amazon",
            "₹5000 - ATM Withdrawal",
            "₹1200 - Swiggy",
            "₹15,000 - Salary Credit",
            "₹3000 - Electricity Bill"
        ],
        "emi_due": "5 April 2026"
    },

    "C102": {
        "name": "Neha Verma",
        "balance": "₹1,25,500",
        "transactions": [
            "₹2500 - Flipkart",
            "₹800 - Uber",
            "₹2000 - Grocery",
            "₹20,000 - Salary Credit",
            "₹4000 - Rent"
        ],
        "emi_due": "10 April 2026"
    }
}


# ================================
# STEP 3: Tool Functions (MCP Tools)
# ================================
def get_balance(customer_id):
    if customer_id in customers:
        return f"💰 Balance: {customers[customer_id]['balance']}"
    return "❌ Customer not found"


def get_transactions(customer_id):
    if customer_id in customers:
        txns = "\n".join(customers[customer_id]['transactions'])
        return f"📜 Last 5 Transactions:\n{txns}"
    return "❌ Customer not found"


def get_emi(customer_id):
    if customer_id in customers:
        return f"📅 EMI Due Date: {customers[customer_id]['emi_due']}"
    return "❌ Customer not found"


# ================================
# STEP 4: Security Layer
# ================================
def secure_access(user_id, requested_id):
    return user_id == requested_id


# ================================
# STEP 5: MCP Agent Logic
# ================================
def banking_agent(message, customer_id, history):

    # simulate logged-in user
    user_id = customer_id

    # security check
    if not secure_access(user_id, customer_id):
        response = "🚫 Access Denied"
        history.append((message, response))
        return "", history

    message_lower = message.lower()

    # ================================
    # Tool Logic
    # ================================
    if "balance" in message_lower:
        response = get_balance(customer_id)

    elif "transaction" in message_lower:
        response = get_transactions(customer_id)

    elif "emi" in message_lower or "loan" in message_lower:
        response = get_emi(customer_id)

    elif "hi" in message_lower or "hello" in message_lower:
        response = "👋 Hello! You can ask about balance, transactions, or EMI."

    else:
        response = "🤖 I can help with balance, transactions, or EMI details."

    # ================================
    # FIXED HISTORY FORMAT ✅
    # ================================
    history.append((message, response))

    return "", history

    # ================================
    # Tool Invocation Logic
    # ================================
    if "balance" in message_lower:
        response = get_balance(customer_id)

    elif "transaction" in message_lower:
        response = get_transactions(customer_id)

    elif "emi" in message_lower or "loan" in message_lower:
        response = get_emi(customer_id)

    elif "hi" in message_lower or "hello" in message_lower:
        response = "👋 Hello! You can ask about balance, transactions, or loan EMI."

    else:
        response = "🤖 I can help with balance, transactions, or EMI details."

    # ================================
    # Store Chat History
    # ================================
    history.append({
        "role": "user",
        "content": message
    })

    history.append({
        "role": "assistant",
        "content": response
    })

    return "", history


# ================================
# STEP 6: Gradio Chat UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🏦 Banking Smart Assistant")

    customer_id = gr.Textbox(
        label="Enter Customer ID (example: C101)"
    )

    chatbot = gr.Chatbot()

    msg = gr.Textbox(
        label="Ask your banking question"
    )

    state = gr.State([])

    msg.submit(
        banking_agent,
        inputs=[msg, customer_id, state],
        outputs=[msg, chatbot]
    )

demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_1032/2862751585.py:156: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# /tmp/ipykernel_1032/2862751585.py:156: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot()
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://26dd5c5df9100c76a2.gradio.live
#
# ...

# %% [markdown]
# banking with api

# %%
# ================================
# STEP 1: Install Libraries
# ================================
# !pip install groq gradio


# ================================
# STEP 2: Setup Groq Client
# ================================
import os
from groq import Groq

# Works for both Colab & local
try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# ================================
# STEP 3: Dummy Database
# ================================
customers = {
    "C101": {
        "name": "Amit Sharma",
        "balance": "₹85,000",
        "transactions": [
            "₹2000 - Amazon",
            "₹5000 - ATM Withdrawal",
            "₹1200 - Swiggy",
            "₹15,000 - Salary Credit",
            "₹3000 - Electricity Bill"
        ],
        "emi_due": "5 April 2026"
    },

    "C102": {
        "name": "Neha Verma",
        "balance": "₹1,25,500",
        "transactions": [
            "₹2500 - Flipkart",
            "₹800 - Uber",
            "₹2000 - Grocery",
            "₹20,000 - Salary Credit",
            "₹4000 - Rent"
        ],
        "emi_due": "10 April 2026"
    }
}


# ================================
# STEP 4: Tool Functions
# ================================
def get_balance(customer_id):
    if customer_id in customers:
        return f"💰 Balance: {customers[customer_id]['balance']}"
    return "❌ Customer not found"


def get_transactions(customer_id):
    if customer_id in customers:
        txns = "\n".join(customers[customer_id]['transactions'])
        return f"📜 Last 5 Transactions:\n{txns}"
    return "❌ Customer not found"


def get_emi(customer_id):
    if customer_id in customers:
        return f"📅 EMI Due Date: {customers[customer_id]['emi_due']}"
    return "❌ Customer not found"


# ================================
# STEP 5: Security Layer
# ================================
def secure_access(user_id, requested_id):
    return user_id == requested_id


# ================================
# STEP 6: MCP Agent (Hybrid)
# ================================
def banking_agent(message, customer_id, history):

    # simulate logged-in user
    user_id = customer_id

    # security check
    if not secure_access(user_id, customer_id):
        response = "🚫 Access Denied"
        history.append((message, response))
        return "", history

    message_lower = message.lower()

    # ================================
    # TOOL LOGIC (FAST + ACCURATE)
    # ================================
    if "balance" in message_lower:
        response = get_balance(customer_id)

    elif "transaction" in message_lower:
        response = get_transactions(customer_id)

    elif "emi" in message_lower or "loan" in message_lower:
        response = get_emi(customer_id)

    elif "hi" in message_lower or "hello" in message_lower:
        response = "👋 Hello! You can ask about balance, transactions, or EMI."

    # ================================
    # LLM CHAT (SMART FALLBACK 🔥)
    # ================================
    else:
        try:
            messages = [
                {
                    "role": "system",
                    "content": (
                        "You are a helpful banking assistant.\n"
                        "You can chat naturally and explain banking concepts.\n"
                        "Guide users politely."
                    )
                }
            ]

            # Add memory
            for user_msg, bot_msg in history:
                messages.append({"role": "user", "content": user_msg})
                messages.append({"role": "assistant", "content": bot_msg})

            messages.append({"role": "user", "content": message})

            response_llm = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                temperature=0.7,
                messages=messages
            )

            response = response_llm.choices[0].message.content.strip()

        except Exception as e:
            print("❌ Groq Error:", e)
            response = "⚠️ Sorry, I couldn't process that."

    # ================================
    # SAVE HISTORY (IMPORTANT FIX ✅)
    # ================================
    history.append((message, response))

    return "", history


# ================================
# STEP 7: Gradio UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🏦 Banking Smart Assistant (Groq Powered)")

    customer_id = gr.Textbox(label="Enter Customer ID (C101 / C102)")

    chatbot = gr.Chatbot(height=400)

    msg = gr.Textbox(label="Ask your banking question")

    state = gr.State([])

    msg.submit(
        banking_agent,
        inputs=[msg, customer_id, state],
        outputs=[msg, chatbot]
    )


# ================================
# STEP 8: Launch App
# ================================
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_1032/1713112862.py:169: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_1032/1713112862.py:169: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://68afc345c836833de9.gradio.live
#
# ...

# %% [markdown]
# SCENARIO: “University Smart Assistant with Role-Based Access”
# 🏫 Background Story
# A university deploys an AI-powered academic assistant to help students, faculty, and administrators.
# 👉 Users can ask:
# - “What is my attendance record?”
# - “Show me my exam results.”
# - “Update course schedules.”
# - “Approve new course registrations.”
# 👉 But not everyone can do everything — access depends on roles.

# %%
# ======================================
# 🎓 UNIVERSITY SMART ASSISTANT (RBAC + GROQ)
# ======================================

# --------------------------------------
# STEP 1: Install Libraries
# --------------------------------------
# !pip install groq gradio


# --------------------------------------
# STEP 2: Setup Groq API
# --------------------------------------
import os
from groq import Groq

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# --------------------------------------
# STEP 3: Dummy Database
# --------------------------------------
students = {
    "S101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "S102": {"name": "Priya", "attendance": 92, "marks": 88},
    "S103": {"name": "Amit", "attendance": 76, "marks": 69}
}


# --------------------------------------
# STEP 4: Tool Functions
# --------------------------------------

# View attendance
def get_attendance(student_id):
    if student_id in students:
        return f"📊 Attendance: {students[student_id]['attendance']}%"
    return "❌ Student not found"


# ✅ FIXED: View results (NEW)
def get_results(student_id):
    if student_id in students:
        return f"📝 Marks: {students[student_id]['marks']}"
    return "❌ Student not found"


# Update results
def update_results(student_id):
    return f"📝 Results updated for {student_id}"


# Admin only
def approve_course_change(student_id):
    return f"✅ Course change approved for {student_id}"


# View all students
def view_all_students():
    return "\n".join([f"{sid}: {data['name']}" for sid, data in students.items()])


# --------------------------------------
# STEP 5: RBAC (FIXED RULES)
# --------------------------------------
def secure_access(role, user_id, target_id, action):

    if role == "admin":
        return True

    elif role == "faculty":
        if action == "approve_course_change":
            return False
        return True

    elif role == "student":
        if user_id != target_id:
            return False
        return action in ["attendance", "view_results"]   # ✅ FIXED

    return False


# --------------------------------------
# STEP 6: LLM INTENT CLASSIFIER (FIXED)
# --------------------------------------
def decide_action(query):
    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0,
            messages=[
                {
                    "role": "system",
                    "content": (
                        "Classify the query into ONE of these:\n"
                        "attendance, view_results, update_results, approve_course_change, view_all, chat\n\n"
                        "Rules:\n"
                        "- If user asks about marks/results → view_results\n"
                        "- If updating → update_results\n"
                        "- Otherwise normal chat → chat\n"
                        "Return ONLY one word."
                    )
                },
                {"role": "user", "content": query}
            ]
        )

        action = response.choices[0].message.content.strip().lower()

        valid = ["attendance", "view_results", "update_results",
                 "approve_course_change", "view_all", "chat"]

        return action if action in valid else "chat"

    except:
        return "chat"


# --------------------------------------
# STEP 7: MAIN AGENT (HYBRID)
# --------------------------------------
def university_agent(message, role, user_id, target_id, history):

    if not user_id:
        response = "⚠️ Enter your ID"
        history.append((message, response))
        return "", history

    if not target_id:
        target_id = user_id

    action = decide_action(message)

    # ============================
    # TOOL EXECUTION
    # ============================
    if action != "chat":

        if not secure_access(role, user_id, target_id, action):
            response = "🚫 Access Denied"

        else:
            if action == "attendance":
                response = get_attendance(target_id)

            elif action == "view_results":   # ✅ FIXED
                response = get_results(target_id)

            elif action == "update_results":
                response = update_results(target_id)

            elif action == "approve_course_change":
                response = approve_course_change(target_id)

            elif action == "view_all":
                response = view_all_students()

    # ============================
    # LLM CHAT
    # ============================
    else:
        try:
            messages = [
                {
                    "role": "system",
                    "content": (
                        "You are a helpful university assistant.\n"
                        "Answer clearly and conversationally."
                    )
                }
            ]

            for u, b in history:
                messages.append({"role": "user", "content": u})
                messages.append({"role": "assistant", "content": b})

            messages.append({"role": "user", "content": message})

            res = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                temperature=0.7,
                messages=messages
            )

            response = res.choices[0].message.content.strip()

        except Exception as e:
            print("LLM Error:", e)
            response = "⚠️ LLM failed"

    history.append((message, response))
    return "", history


# --------------------------------------
# STEP 8: Gradio UI
# --------------------------------------
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🎓 University Smart Assistant (RBAC + Groq)")

    role = gr.Dropdown(
        ["student", "faculty", "admin"],
        label="Select Role"
    )

    user_id = gr.Textbox(label="Your ID (S101)")
    target_id = gr.Textbox(label="Target Student ID (optional)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        university_agent,
        inputs=[msg, role, user_id, target_id, state],
        outputs=[msg, chatbot]
    )


# --------------------------------------
# STEP 9: Launch
# --------------------------------------
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_3408/3453098862.py:219: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_3408/3453098862.py:219: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ff4324c767f170cc11.gradio.live
#
# ...

# %% [markdown]
# SCENARIO: “Retail Smart Assistant with Role-Based Access”
# 🏬 Background Story
# A large retail chain introduces an AI-powered store assistant to streamline operations.
# 👉 Users can ask:
# - “What is my purchase history?”
# - “Check inventory for product X.”
# - “Approve supplier orders.”
# - “Manage employee schedules.”
# 👉 But not everyone can do everything — access depends on roles.

# %%
# ======================================
# 🏬 RETAIL SMART ASSISTANT (RBAC + GROQ)
# ======================================

# --------------------------------------
# STEP 1: Install Libraries
# --------------------------------------
# !pip install groq gradio


# --------------------------------------
# STEP 2: Setup Groq API
# --------------------------------------
import os
from groq import Groq

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# --------------------------------------
# STEP 3: Dummy Retail Database
# --------------------------------------
customers = {
    "C101": {
        "name": "Amit",
        "purchases": ["Nike Shoes", "T-shirt", "Watch"]
    },
    "C102": {
        "name": "Neha",
        "purchases": ["Handbag", "Perfume", "Dress"]
    }
}

inventory = {
    "Nike Shoes": 25,
    "T-shirt": 50,
    "Watch": 15,
    "Handbag": 20,
    "Perfume": 30
}


# --------------------------------------
# STEP 4: Tool Functions
# --------------------------------------

# View purchase history
def get_purchase_history(customer_id):
    if customer_id in customers:
        items = "\n".join(customers[customer_id]["purchases"])
        return f"🛍️ Purchase History:\n{items}"
    return "❌ Customer not found"


# View others' purchases
def view_all_purchases():
    result = ""
    for cid, data in customers.items():
        result += f"{cid}: {', '.join(data['purchases'])}\n"
    return result


# Check inventory
def check_inventory(product):
    if product in inventory:
        return f"📦 {product} stock: {inventory[product]}"
    return "❌ Product not found"


# Manager only
def approve_supplier_order():
    return "✅ Supplier order approved"


# Manager only
def manage_schedules():
    return "📅 Employee schedules updated"


# --------------------------------------
# STEP 5: RBAC (FROM YOUR IMAGE)
# --------------------------------------
def secure_access(role, user_id, target_id, action):

    # Manager → full access
    if role == "manager":
        return True

    # Staff rules
    elif role == "staff":
        if action in ["approve_order", "manage_schedule"]:
            return False
        return True

    # Customer rules
    elif role == "customer":
        if action == "view_own":
            return user_id == target_id
        return False

    return False


# --------------------------------------
# STEP 6: LLM INTENT CLASSIFIER
# --------------------------------------
def decide_action(query):
    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0,
            messages=[
                {
                    "role": "system",
                    "content": (
                        "Classify query into ONE of these:\n"
                        "view_own, view_others, inventory, approve_order, manage_schedule, chat\n\n"
                        "Rules:\n"
                        "- purchase history → view_own or view_others\n"
                        "- inventory → inventory\n"
                        "- supplier approval → approve_order\n"
                        "- schedules → manage_schedule\n"
                        "- otherwise → chat\n"
                        "Return ONLY one word."
                    )
                },
                {"role": "user", "content": query}
            ]
        )

        action = response.choices[0].message.content.strip().lower()

        valid = [
            "view_own", "view_others", "inventory",
            "approve_order", "manage_schedule", "chat"
        ]

        return action if action in valid else "chat"

    except:
        return "chat"


# --------------------------------------
# STEP 7: MAIN AGENT
# --------------------------------------
def retail_agent(message, role, user_id, target_id, product, history):

    if not user_id:
        response = "⚠️ Enter your ID"
        history.append((message, response))
        return "", history

    if not target_id:
        target_id = user_id

    action = decide_action(message)

    # ============================
    # TOOL EXECUTION
    # ============================
    if action != "chat":

        if not secure_access(role, user_id, target_id, action):
            response = "🚫 Access Denied"

        else:
            if action == "view_own":
                response = get_purchase_history(user_id)

            elif action == "view_others":
                response = view_all_purchases()

            elif action == "inventory":
                response = check_inventory(product)

            elif action == "approve_order":
                response = approve_supplier_order()

            elif action == "manage_schedule":
                response = manage_schedules()

    # ============================
    # LLM CHAT
    # ============================
    else:
        try:
            messages = [
                {
                    "role": "system",
                    "content": "You are a helpful retail assistant."
                }
            ]

            for u, b in history:
                messages.append({"role": "user", "content": u})
                messages.append({"role": "assistant", "content": b})

            messages.append({"role": "user", "content": message})

            res = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                temperature=0.7,
                messages=messages
            )

            response = res.choices[0].message.content.strip()

        except:
            response = "⚠️ Could not process request"

    history.append((message, response))
    return "", history


# --------------------------------------
# STEP 8: Gradio UI
# --------------------------------------
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🏬 Retail Smart Assistant (RBAC + Groq)")

    role = gr.Dropdown(
        ["customer", "staff", "manager"],
        label="Select Role"
    )

    user_id = gr.Textbox(label="Your ID (C101)")
    target_id = gr.Textbox(label="Target Customer ID (optional)")
    product = gr.Textbox(label="Product Name (for inventory)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        retail_agent,
        inputs=[msg, role, user_id, target_id, product, state],
        outputs=[msg, chatbot]
    )


# --------------------------------------
# STEP 9: Launch
# --------------------------------------
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_3408/3865403198.py:240: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_3408/3865403198.py:240: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://88e42b5b960af7b86f.gradio.live
#
# ...

# %% [markdown]
# # SCENARIO: “Corporate Research Assistant System”
#  🏢 Background Story
#  A multinational company deploys an AI-powered business intelligence assistant.
#  👉 Employees can ask:
#  - “What’s the latest news about Tesla?”
#  - “What’s Tesla’s current stock price?”
#  - “Give me a company profile instantly.”
#  👉 Instead of manually searching news sites, finance portals, and HR databases,
#  👉 AI fetches all the data in parallel, analyzes it, and generates a professional report.
#
#  ⚙️ How it works (mapped to your pipeline):
#  - Parallel Data Collection → AI gathers news, stock prices, and company profiles simultaneously.
#  - LLM Analysis → AI interprets the combined data, highlighting key insights.
#  - Report Generation → AI produces a polished, executive-ready report.
#
#  💡 Impact:
#  - Saves analysts hours of manual research.
#  - Provides real-time, consolidated insights for decision-making.
# - Empowers managers with instant reports for board meetings or investor updates.

# %%
# ======================================
# 🏢 CORPORATE RESEARCH ASSISTANT (GROQ)
# ======================================

# --------------------------------------
# STEP 1: Install Libraries
# --------------------------------------
# !pip install groq gradio


# --------------------------------------
# STEP 2: Setup Groq API
# --------------------------------------
import os
from groq import Groq
import time
import concurrent.futures

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# --------------------------------------
# STEP 3: Simulated Data Sources (APIs)
# --------------------------------------

# 📰 News API (mock)
def fetch_news(company):
    time.sleep(1)  # simulate delay
    return [
        f"{company} expands into AI market",
        f"{company} stock sees volatility this week",
        f"{company} announces new partnership"
    ]


# 📈 Stock API (mock)
def fetch_stock(company):
    time.sleep(1)
    return {
        "price": "$245.30",
        "change": "+2.3%",
        "trend": "Bullish"
    }


# 🏢 Company Profile API (mock)
def fetch_profile(company):
    time.sleep(1)
    return {
        "name": company,
        "industry": "Technology",
        "ceo": "Elon Musk",
        "employees": "140,000"
    }


# --------------------------------------
# STEP 4: Parallel Data Collection
# --------------------------------------
def gather_data(company):

    with concurrent.futures.ThreadPoolExecutor() as executor:
        news_future = executor.submit(fetch_news, company)
        stock_future = executor.submit(fetch_stock, company)
        profile_future = executor.submit(fetch_profile, company)

        news = news_future.result()
        stock = stock_future.result()
        profile = profile_future.result()

    return news, stock, profile


# --------------------------------------
# STEP 5: LLM Analysis + Report
# --------------------------------------
def generate_report(company, news, stock, profile):

    try:
        prompt = f"""
        You are a corporate research analyst.

        Create a professional business report.

        Company: {company}

        News:
        {news}

        Stock Data:
        {stock}

        Company Profile:
        {profile}

        Include:
        - Summary
        - Key Insights
        - Risk Analysis
        - Conclusion
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0.5,
            messages=[{"role": "user", "content": prompt}]
        )

        return response.choices[0].message.content.strip()

    except Exception as e:
        print("LLM Error:", e)
        return "⚠️ Failed to generate report"


# --------------------------------------
# STEP 6: Main Agent
# --------------------------------------
def research_agent(message, history):

    # Extract company name (simple version)
    company = message.strip()

    # Step 1: Gather data in parallel
    news, stock, profile = gather_data(company)

    # Step 2: Generate report using LLM
    report = generate_report(company, news, stock, profile)

    history.append((message, report))
    return "", history


# --------------------------------------
# STEP 7: Gradio UI
# --------------------------------------
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🏢 Corporate Research Assistant")

    chatbot = gr.Chatbot(height=500)

    msg = gr.Textbox(label="Enter company name (e.g., Tesla)")

    state = gr.State([])

    msg.submit(
        research_agent,
        inputs=[msg, state],
        outputs=[msg, chatbot]
    )


# --------------------------------------
# STEP 8: Launch
# --------------------------------------
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_3408/864066587.py:149: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=500)
# /tmp/ipykernel_3408/864066587.py:149: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=500)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://17c33996725c3c2b40.gradio.live
#
# ...

# %% [markdown]
# 🏥 SCENARIO: “Healthcare Research Assistant System”
# 🩺 Background Story
# A medical research institute deploys an AI-powered clinical intelligence assistant.
# 👉 Researchers and doctors can ask:
# • 	“What’s the latest research on diabetes treatments?”
# • 	“Summarize recent clinical trial results for cancer drugs.”
# • 	“Give me a profile of a pharmaceutical company instantly.”
# 👉 Instead of manually searching journals, trial databases, and company reports,
# 👉 AI fetches all the data in parallel, analyzes it, and generates a professional research summary.
#
# ⚙️ How it works (mapped to your pipeline):
# • 	Parallel Data Collection → AI gathers medical news, trial results, and company profiles simultaneously.
# • 	LLM Analysis → AI interprets the combined data, highlighting key medical insights.
# • 	Report Generation → AI produces a polished, researcher-ready report.

# %%
# ======================================
# 🏥 HEALTHCARE RESEARCH ASSISTANT (GROQ)
# ======================================

# --------------------------------------
# STEP 1: Install Libraries
# --------------------------------------
# !pip install groq gradio


# --------------------------------------
# STEP 2: Setup Groq API
# --------------------------------------
import os
import time
import concurrent.futures
from groq import Groq

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# --------------------------------------
# STEP 3: Simulated Medical Data Sources
# --------------------------------------

# 📰 Medical News
def fetch_medical_news(topic):
    time.sleep(1)
    return [
        f"New breakthrough in {topic} treatment using AI-assisted drugs",
        f"Global study shows improved outcomes in {topic} patients",
        f"WHO releases updated guidelines for {topic}"
    ]


# 🧪 Clinical Trials
def fetch_clinical_trials(topic):
    time.sleep(1)
    return [
        f"Phase 3 trial shows 65% success rate for new {topic} drug",
        f"Combination therapy improves survival rate in {topic}",
        f"New immunotherapy shows promising results in early trials"
    ]


# 🏢 Pharma Company Profiles
def fetch_pharma_profiles(topic):
    time.sleep(1)
    return {
        "companies": [
            f"Pfizer working on {topic} vaccines",
            f"Moderna developing mRNA-based {topic} treatments",
            f"Novartis investing heavily in {topic} research"
        ]
    }


# --------------------------------------
# STEP 4: Parallel Data Collection
# --------------------------------------
def gather_medical_data(topic):

    with concurrent.futures.ThreadPoolExecutor() as executor:
        news_future = executor.submit(fetch_medical_news, topic)
        trials_future = executor.submit(fetch_clinical_trials, topic)
        pharma_future = executor.submit(fetch_pharma_profiles, topic)

        news = news_future.result()
        trials = trials_future.result()
        pharma = pharma_future.result()

    return news, trials, pharma


# --------------------------------------
# STEP 5: LLM Analysis + Report
# --------------------------------------
def generate_medical_report(topic, news, trials, pharma):

    try:
        prompt = f"""
        You are a medical research assistant.

        Generate a professional healthcare research report.

        Topic: {topic}

        Medical News:
        {news}

        Clinical Trials:
        {trials}

        Pharma Companies:
        {pharma}

        Include:
        - Overview of topic
        - Key Research Findings
        - Clinical Insights
        - Industry Trends
        - Risks & Limitations
        - Conclusion

        Keep it clear and suitable for doctors/researchers.
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0.4,
            messages=[{"role": "user", "content": prompt}]
        )

        return response.choices[0].message.content.strip()

    except Exception as e:
        print("LLM Error:", e)
        return "⚠️ Failed to generate medical report"


# --------------------------------------
# STEP 6: Main Agent
# --------------------------------------
def healthcare_agent(message, history):

    topic = message.strip()

    # Step 1: Parallel data collection
    news, trials, pharma = gather_medical_data(topic)

    # Step 2: LLM analysis
    report = generate_medical_report(topic, news, trials, pharma)

    history.append((message, report))
    return "", history


# --------------------------------------
# STEP 7: Gradio UI
# --------------------------------------
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("# 🏥 Healthcare Research Assistant")

    chatbot = gr.Chatbot(height=500)

    msg = gr.Textbox(label="Enter topic (e.g., diabetes, cancer drugs)")

    state = gr.State([])

    msg.submit(
        healthcare_agent,
        inputs=[msg, state],
        outputs=[msg, chatbot]
    )


# --------------------------------------
# STEP 8: Launch
# --------------------------------------
demo.launch(share=True)
# Out:
# ...
# /tmp/ipykernel_3408/1623378092.py:153: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=500)
# /tmp/ipykernel_3408/1623378092.py:153: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=500)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f2ce6e0d520a09cfb4.gradio.live
#
# ...

# %%
# 🖥️ SCENARIO: “AI IT Helpdesk Assistant in a Large Company”
# 🏢 Background Story

# A large company (like Infosys or TCS) has thousands of employees.

# 👉 Employees face issues daily:

# VPN not working
# System hacked
# Email access denied
# Network outage

# 👉 Instead of manual IT support, the company builds an:

# 🤖 AI IT Helpdesk Assistant


# ======================================
# STEP 1: Install Dependencies
# ======================================
# !pip install groq


# ======================================
# STEP 2: Load API Key from Colab Secrets
# ======================================
from google.colab import userdata
from groq import Groq
import asyncio
import random
import logging

logging.basicConfig(level=logging.INFO)

groq_api_key = userdata.get("GROQ_API_KEY")
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 3: Simulated MCP Tools (Mock APIs)
# ======================================
async def page_security_team(payload):
    return "🚨 Security team paged"

async def create_jira_ticket(payload):
    return f"🎫 Jira ticket created: {payload}"

async def check_network_status(payload):
    return random.choice(["Network degraded", "All systems normal"])

async def alert_noc_team(payload):
    return "📡 NOC team alerted"

async def get_ad_user(payload):
    return "user_123"

async def reset_permissions(payload):
    return "🔐 Permissions reset successfully"

async def query_postgres(payload):
    if random.random() < 0.7:
        raise Exception("Database timeout")
    return "📦 Data from Postgres"

async def query_sqlite_cache(payload):
    return "🗂 Data from SQLite cache (fallback)"


# ======================================
# STEP 4: LLM Classifier via Groq
# ======================================
def classify_issue(issue):
    prompt = f"""
    Classify the following IT issue into ONE category only:
    network, hardware, software, security, access

    Issue: {issue}

    Return only the category name.
    """

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content.strip().lower()


# ======================================
# STEP 5: Conditional Routing Logic
# ======================================
async def smart_it_triage(issue, severity):
    issue_type = classify_issue(issue)

    print(f"🧠 Classified as: {issue_type}")

    if issue_type == "security":
        await page_security_team({"issue": issue})
        return await create_jira_ticket({"project": "SEC", "priority": "Blocker"})

    elif issue_type == "network" and severity == "high":
        status = await check_network_status({})
        if "degraded" in status.lower():
            return await alert_noc_team({"issue": issue})
        else:
            return await create_jira_ticket({"project": "NET", "priority": "High"})

    elif issue_type == "access":
        user = await get_ad_user({"query": issue})
        return await reset_permissions({"user": user})

    else:
        return await create_jira_ticket({"project": "IT", "priority": "Medium"})


# ======================================
# STEP 6: Retry with Exponential Backoff
# ======================================
async def call_tool_with_retry(
    primary_tool,
    fallback_tool=None,
    max_retries=3
):
    delay = 1

    for attempt in range(max_retries):
        try:
            return await primary_tool({})
        except Exception as e:
            logging.warning(f"Attempt {attempt+1} failed: {e}")

            if attempt == max_retries - 1:
                if fallback_tool:
                    logging.info("Switching to fallback tool")
                    return await fallback_tool({})
                raise

            await asyncio.sleep(delay)
            delay *= 2


# ======================================
# STEP 7: Run Demo
# ======================================
async def run_demo():
    print("=== Smart IT Triage Demo ===")

    result = await smart_it_triage(
        issue="VPN not working for employee",
        severity="high"
    )

    print("🔍 Routing Result:", result)

    print("\n=== Retry Pattern Demo ===")

    data = await call_tool_with_retry(
        query_postgres,
        fallback_tool=query_sqlite_cache
    )

    print("📊 Data Result:", data)


# ======================================
# STEP 8: Execute (Colab-safe)
# ======================================
await run_demo()
# Out:
# ...
# === Smart IT Triage Demo ===
# 🧠 Classified as: security
# 🔍 Routing Result: 🎫 Jira ticket created: {'project': 'SEC', 'priority': 'Blocker'}
#
# === Retry Pattern Demo ===
# 📊 Data Result: 📦 Data from Postgres

# %% [markdown]
# SCENARIO: “AI Healthcare Support Assistant in a Large Hospital”
# 🏢 Background Story
# A large hospital (like Apollo or Fortis) has thousands of patients and staff members.
# 👉 Daily Challenges Faced:
# - Patients waiting hours for appointment confirmations
# - Confusion about lab test results and reports
# - Doctors overwhelmed with scheduling and follow-up reminders
# - Nurses struggling to track medicine administration times
# - Emergency cases needing instant triage
# 👉 Instead of manual coordination, the hospital builds an:
# 🤖 AI Healthcare Support Assistant
# 🚑 Capabilities:
# - 📅 Smart Scheduling: Automatically books and reschedules patient appointments based on doctor availability.
# - 🧪 Lab Report Explainer: Summarizes test results in simple language for patients.
# - 💊 Medication Tracker: Sends reminders to nurses and patients about dosage timings.
# - 🚨 Emergency Triage: Instantly categorizes incoming cases (critical, urgent, routine) and alerts the right medical team.
# - 📧 Follow-up Automation: Sends personalized recovery instructions and reminders after discharge.
# 🎯 Impact:
# - Reduced patient waiting time
# - Doctors spend more time on treatment, less on admin work
# - Nurses avoid errors in medicine administration
# - Faster response in emergencies
# - Improved patient satisfaction and trust

# %%
# ======================================
# 🏥 AI HEALTHCARE SUPPORT ASSISTANT
# ======================================

# --------------------------------------
# STEP 1: Install Dependencies
# --------------------------------------
# !pip install groq


# --------------------------------------
# STEP 2: Setup Groq API
# --------------------------------------
import os
import asyncio
import random
from groq import Groq

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY")
except:
    groq_api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=groq_api_key)


# --------------------------------------
# STEP 3: Simulated Hospital Tools
# --------------------------------------

# 📅 Appointment system
async def book_appointment(payload):
    return f"📅 Appointment booked with Dr. {payload['doctor']} at {payload['time']}"

# 🧪 Lab report fetch
async def fetch_lab_report(payload):
    return {
        "patient": payload["patient"],
        "report": "Blood sugar slightly high, cholesterol normal"
    }

# 💊 Medication reminder
async def send_medication_alert(payload):
    return f"💊 Reminder sent for {payload['medicine']} at {payload['time']}"

# 🚨 Emergency alert
async def alert_emergency_team(payload):
    return f"🚨 {payload['severity'].upper()} case! Emergency team alerted"

# 📧 Follow-up message
async def send_followup(payload):
    return f"📧 Follow-up sent: {payload['message']}"


# --------------------------------------
# STEP 4: LLM Classifier (Intent + Triage)
# --------------------------------------
def classify_request(query):
    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0,
            messages=[
                {
                    "role": "system",
                    "content": (
                        "Classify into ONE:\n"
                        "appointment, lab, medication, emergency, followup, chat\n\n"
                        "Rules:\n"
                        "- appointment booking → appointment\n"
                        "- lab/test/report → lab\n"
                        "- medicine/reminder → medication\n"
                        "- critical/pain/accident → emergency\n"
                        "- recovery/instructions → followup\n"
                        "- otherwise → chat\n"
                        "Return ONE word only."
                    )
                },
                {"role": "user", "content": query}
            ]
        )

        result = response.choices[0].message.content.strip().lower()

        valid = ["appointment", "lab", "medication", "emergency", "followup", "chat"]

        return result if result in valid else "chat"

    except:
        return "chat"


# --------------------------------------
# STEP 5: Emergency Severity Detection
# --------------------------------------
def detect_severity(query):
    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0,
            messages=[
                {
                    "role": "system",
                    "content": (
                        "Classify severity into ONE:\n"
                        "critical, urgent, routine\n"
                        "Return only one word."
                    )
                },
                {"role": "user", "content": query}
            ]
        )

        return response.choices[0].message.content.strip().lower()

    except:
        return "routine"


# --------------------------------------
# STEP 6: Lab Report Explanation (LLM)
# --------------------------------------
def explain_lab_report(report):
    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            temperature=0.6,
            messages=[
                {
                    "role": "system",
                    "content": (
                        "Explain medical report in simple language for patients."
                    )
                },
                {"role": "user", "content": str(report)}
            ]
        )

        return response.choices[0].message.content.strip()

    except:
        return "⚠️ Could not explain report"


# --------------------------------------
# STEP 7: MAIN AGENT
# --------------------------------------
async def healthcare_agent(query):

    intent = classify_request(query)
    print(f"🧠 Intent: {intent}")

    try:
        # 📅 Appointment
        if intent == "appointment":
            return await book_appointment({
                "doctor": "Sharma",
                "time": "10:30 AM"
            })

        # 🧪 Lab Report
        elif intent == "lab":
            report = await fetch_lab_report({"patient": "Rahul"})
            explanation = explain_lab_report(report)
            return f"🧪 Report:\n{report}\n\n🧠 Explanation:\n{explanation}"

        # 💊 Medication
        elif intent == "medication":
            return await send_medication_alert({
                "medicine": "Paracetamol",
                "time": "8 PM"
            })

        # 🚨 Emergency
        elif intent == "emergency":
            severity = detect_severity(query)
            return await alert_emergency_team({"severity": severity})

        # 📧 Follow-up
        elif intent == "followup":
            return await send_followup({
                "message": "Take rest, stay hydrated, and follow doctor advice."
            })

        # 💬 Chat
        else:
            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                temperature=0.7,
                messages=[
                    {"role": "system", "content": "You are a helpful hospital assistant."},
                    {"role": "user", "content": query}
                ]
            )
            return response.choices[0].message.content.strip()

    except Exception as e:
        return f"⚠️ System error: {e}"


# --------------------------------------
# STEP 8: Demo Runner
# --------------------------------------
async def run_demo():

    print("=== 🏥 Healthcare Assistant Demo ===")

    queries = [
        "Book appointment with doctor",
        "Explain my blood test report",
        "Remind me to take medicine",
        "Patient has chest pain and difficulty breathing",
        "Send recovery instructions"
    ]

    for q in queries:
        print(f"\n👤 Query: {q}")
        result = await healthcare_agent(q)
        print("🤖 Response:", result)


# --------------------------------------
# STEP 9: Run
# --------------------------------------
await run_demo()
# Out:
# ...
# === 🏥 Healthcare Assistant Demo ===
#
# 👤 Query: Book appointment with doctor
# 🧠 Intent: appointment
# 🤖 Response: 📅 Appointment booked with Dr. Sharma at 10:30 AM
#
# 👤 Query: Explain my blood test report
# 🧠 Intent: lab
# 🤖 Response: 🧪 Report:
# {'patient': 'Rahul', 'report': 'Blood sugar slightly high, cholesterol normal'}
#
# 🧠 Explanation:
# **Your Medical Report, Rahul**
#
# We've reviewed your test results, and here's what we found:
#
# * **Blood Sugar:** Your blood sugar level is a bit higher than normal. This means you might need to make some changes to your diet or lifestyle to keep it under control.
# * **Cholesterol:** The good news is that your cholesterol level is normal. This suggests you're doing well in terms of heart health.
#
# **What's Next?**
#
# We recommend that you:
#
# * Talk to your doctor about ways to lower your blood sugar level
# * Continue to eat a healthy, balanced diet
# * Exercise regularly to stay healthy
# ...

# %%
import nbformat
import os

notebook_name = 'day27_Advance_mcp.ipynb'
fixed_notebook_name = notebook_name.replace('.ipynb', '_cleaned.ipynb')

if not os.path.exists(notebook_name):
    print(f'Error: The notebook file {notebook_name} was not found.')
    print('Please upload the notebook file you wish to fix to your environment or provide the correct path.')
else:
    with open(notebook_name, 'r', encoding='utf-8') as f:
        nb = nbformat.read(f, as_version=4)
    nb['metadata'] = {}
    with open(fixed_notebook_name, 'w', encoding='utf-8') as f:
        nbformat.write(nb, f)
    print(f'Fixed notebook saved to {fixed_notebook_name}!')
